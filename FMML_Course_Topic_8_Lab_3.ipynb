# %% [markdown]
# <a href="https://colab.research.google.com/github/rishithapemmireddy/fmmlabs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 15:27:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   195MB/s    in 0.4s
#
# 2024-03-31 15:27:24 (195 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(200, 300) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(200, 300) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 28397  1706.04717v1  Face synthesis has been a fascinating yet chal...    cs
# 26824  1611.09811v1  Three-dimensional Ultrasound image segmentatio...    cs
# 16406  1702.02390v1  In this paper we explore the effect of archite...    cs
# 35123  cs/9710101v1  A fundamental goal of research in molecular bi...    cs
# 36054   1210.1785v1  We address the relative expressiveness of defe...    cs
# ...             ...                                                ...   ...
# 13109  1605.01278v4  Learning from demonstration (LfD) is the proce...  stat
# 38505   0705.1674v1  This paper investigates the use of evolutionar...    cs
# 22151  1506.00553v1  This paper examines the use of a residual boot...  stat
# 25741  1511.04534v2  We propose a novel approach to enhance the dis...    cs
# 29629  1709.10177v1  Feature curves are largely adopted to highligh...    cs
#
#                                                    title  year  \
# 28397            Recent Progress of Face Image Synthesis  2017
# 26824         3D Ultrasound image segmentation: A Survey  2016
# 16406  A Hybrid Convolutional Variational Autoencoder...  2017
# 35123       Analysis of Three-Dimensional Protein Images  1997
# 36054       Relative Expressiveness of Defeasible Logics  2012
# ...                                                  ...   ...
# 13109  A Bayesian Approach to Policy Recognition and ...  2016
# 38505  Evolutionary Optimisation Methods for Template...  2007
# 22151    Bootstrap Bias Corrections for Ensemble Methods  2015
# 25741  Learning Fine-grained Features via a CNN Tree ...  2015
# 29629  Recognition of feature curves on 3D shapes usi...  2017
#
#                                                 keywords
# 28397  [synthesis, fascinating, challenging, algorith...
# 26824  [dimensional, ultrasound, segmentation, invest...
# 16406  [architectural, variational, autoencoder, gene...
# 35123  [fundamental, molecular, understand, structure...
# 36054  [expressiveness, defeasible, framework, expres...
# ...                                                  ...
# 13109  [demonstration, behavioral, demonstrations, ge...
# 38505  [investigates, evolutionary, optimisation, tec...
# 22151  [bootstrap, correction, regression, accounting...
# 25741  [discriminability, convolutional, structure, p...
# 29629  [highlight, meaningful, extracting, sufficient...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 28397    [synthesis, fascinating, challenging, algorith...
# 26824    [dimensional, ultrasound, segmentation, invest...
# 16406    [architectural, variational, autoencoder, gene...
# 35123    [fundamental, molecular, understand, structure...
# 36054    [expressiveness, defeasible, framework, expres...
#                                ...
# 2602     [observation, variational, posteriors, observa...
# 22427    [probabilistic, framework, collective, behavio...
# 2499     [trajectory, recovering, observations, fundame...
# 6779     [demonstrated, different, algorithms, intensiv...
# 34209    [remarkable, attention, accessing, technologie...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8697 words.
# Out of those 4557 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6b97f8ac-4044-44f3-bc83-e7f57f13aa14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b97f8ac-4044-44f3-bc83-e7f57f13aa14")) {                    Plotly.newPlot(                        "6b97f8ac-4044-44f3-bc83-e7f57f13aa14",                        [{"x":["synthesis","challenging","recognition","discussing","furthermore","fascinating","preserving","evaluation","realistic","difficulties","excellent","highlighted","algorithms","introduced","probability","available","approaches","generative","traditional","adversarial","comprehensive","promising","complicated","databases","distributions","particularly","directions","segmentation","literature","presented","addressed","considered","applications","comparison","utilizing","ultrasound","tabulated","technique","robustness","interactivity","techniques","dimensional","investigate","autoencoder","recurrent","attractive","convergence","generation","previously","importantly","deconvolutional","convolutional","properties","variational","architecture","architectural","components","sequences","structure","understand","conformation","methodologies","molecular","resolution","currently","formulated","prediction","classification","described","substructures","intensive","meaningful","representation","segmented","successful","determining","determination","computational","fundamental","certainty","methodology","different","expressive","simulations","differently","reasoning","expressiveness","ambiguity","propagating","defeasible","formulation","framework","capability","streaming","reformulate","principled","generalized","stochastic","subsequently","stationarity","corresponding","regularization","distribution","regression","simulated","particular","constraint","parameter","ubiquitous","stationary","iteratively","application","underlying","incremental","regularized","sequentially","neuroimaging","estimating","variables","numerical","constraints","identifiability","expansion","optimization","assumptions","conditions","arbitrary","correlations","unsupervised","sufficient","primarily","estimation","probabilistic","tractable","experiments","statistics","including","important","challenges","extremely","requirements","highlight","complexity","incorporates","synthetic","challenge","experimental","substantial","dimensionality","difficulty","variations","hyperspectral","competitively","variation","diffusion","dramatically","clustering","detection","nonlinear","significant","segmenting","benchmark","discussed","information","extensive","efficiently","contribute","parameters","demonstrate","geometric","automatically","empirical","inherently","connectivity","uncertainty","estimators","effectively","difference","estimator","differences","covariance","statistical","comparing","parametric","estimated","populations","efficient","functional","interpretable","guarantees","characterizing","introduce","characterize","intervals","penalties","graphical","characterized","confidence","extension","backtracking"],"y":[44,285,395,12,154,2,47,266,62,34,29,5,589,137,171,293,446,135,176,112,54,114,30,68,111,83,34,212,134,192,40,129,433,139,52,6,1,292,112,3,400,158,139,30,150,33,107,139,96,30,6,351,200,47,267,9,114,107,353,55,2,21,7,126,51,43,221,490,60,4,34,47,360,26,86,35,15,277,82,7,72,735,32,45,8,121,9,20,15,3,84,544,62,14,6,26,60,120,34,3,129,80,194,117,59,251,88,127,15,18,37,224,112,29,34,17,8,61,104,100,163,4,13,347,68,138,95,30,146,76,25,200,182,20,599,59,252,331,122,51,53,24,223,38,161,147,371,53,46,48,84,13,6,62,25,16,153,328,48,257,16,209,63,717,195,146,40,243,550,77,195,159,19,21,86,8,113,63,19,45,14,164,78,25,59,15,389,44,29,54,21,305,41,8,4,55,35,36,70,6],"type":"bar"},{"x":["synthesis","challenging","recognitio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4557,), (4557, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8266666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifying</span> <span style=''>Harm</span> <span style=''>Events</span> <span style=''>in</span> <span style=''>Clinical</span> <span style=''>Care</span> <span style=''>through</span> <span style=''>Medical</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Narratives</span> <br/><br/><span style=''>Preventable</span> <span style=''>medical</span> <span style=''>errors</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>to</span> <span style=''>be</span> <span style=''>among</span> <span style=''>the</span> <span style=''>leading</span> <span style=''>causes</span> <span style=''>of</span> <span style=''>injury</span> <span style=''>and</span> <span style=''>death</span> <span style=''>in</span> <span style=''>the</span> <span style=''>United</span> <span style=''>States</span> <span style=''>To</span> <span style=''>prevent</span> <span style=''>such</span> <span style=''>errors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>healthcare</span> <span style=''>systems</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3888888888888889);'>implemented</span> <span style=''>patient</span> <span style=''>safety</span> <span style=''>and</span> <span style=''>incident</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>reporting</span> <span style=''>systems</span> <span style=''>These</span> <span style=''>systems</span> <span style=''>enable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clinicians</span> <span style=''>to</span> <span style=''>report</span> <span style=''>unsafe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>and</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>patients</span> <span style=''>have</span> <span style=''>been</span> <span style=''>harmed</span> <span style=''>due</span> <span style=''>to</span> <span style=''>errors</span> <span style=''>in</span> <span style=''>medical</span> <span style=''>care</span> <span style=''>These</span> <span style=''>reports</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>narratives</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>and</span> <span style=''>while</span> <span style=''>they</span> <span style=''>provide</span> <span style=''>detailed</span> <span style='background-color:rgba(0, 255, 0, 0.31318681318681335);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situation</span> <span style=''>it</span> <span style=''>is</span> <span style=''>non</span> <span style=''>trivial</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>analysis</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>common</span> <span style=''>causes</span> <span style=''>of</span> <span style=''>errors</span> <span style=''>and</span> <span style=''>harm</span> <span style=''>to</span> <span style=''>the</span> <span style=''>patients</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>attentive</span> <span style='background-color:rgba(0, 255, 0, 0.6027397260273972);'>convolutional</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.48514851485148514);'>recurrent</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3); ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>with</span> <span style=''>many</span> <span style=''>experts</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>sparsity</span> <br/><br/><span style=''>Experts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifying</span> <span style=''>data</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imprecise</span> <span style=''>Recently</span> <span style=''>several</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>using</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>labels</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>these</span> <span style=''>experts</span> <span style=''>How</span> <span style=''>to</span> <span style=''>choose</span> <span style=''>between</span> <span style=''>these</span> <span style=''>models</span> <span style=''>In</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>the</span> <span style=''>true</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unavailable</span> <span style=''>Thus</span> <span style=''>one</span> <span style=''>cannot</span> <span style=''>perform</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>using</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>and</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>loss</span> <span style=''>and</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>that</span> <span style=''>assure</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>Next</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>how</span> <span style=''>this</span> <span style=''>loss</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>tune</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalization</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>class</span> <span style=''>of</span> <span style=''>models</span> <span style=''>Sparsity</span> <span style=''>provides</span> <span style=''>more</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.44444444444444453);'>Hamiltonian</span> <span style=''>Annealed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Importance</span> <span style=''>Sampling</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>to</span> <span style=''>annealed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>that</span> <span style=''>uses</span> <span style='background-color:rgba(255, 0, 0, 0.44444444444444453);'>Hamiltonian</span> <span style=''>dynamics</span> <span style=''>to</span> <span style=''>rapidly</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constants</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>this</span> <span style=''>method</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.5833333333333335);'>likelihoods</span> <span style=''>in</span> <span style=''>directed</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5757575757575758);'>undirected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>image</span> <span style=''>models</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>with</span> <span style=''>both</span> <span style=''>Gaussian</span> <span style=''>and</span> <span style=''>Laplace</span> <span style=''>priors</span> <span style=''>product</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>models</span> <span style=''>with</span> <span style=''>Laplace</span> <span style=''>and</span> <span style=''>Students</span> <span style=''>t</span> <span style=''>experts</span> <span style=''>the</span> <span style=''>mc</span> <span style=''>RBM</span> <span style=''>and</span> <span style=''>a</span> <span style=''>bilinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>code</span> <span style=''>to</span> <span style=''>compare</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>models</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Distance</span> <span style=''>Metric</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Kernel</span> <span style=''>Machines</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>in</span> <span style=''>metric</span> <span style=''>learning</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>improved</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>Support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SVM)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>with</span> <span style=''>RBF</span> <span style=''>kernels</span> <span style=''>are</span> <span style=''>amongst</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>distance</span> <span style=''>metrics</span> <span style=''>to</span> <span style=''>compare</span> <span style=''>examples</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>efficacy</span> <span style=''>of</span> <span style=''>three</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mahalanobis</span> <span style=''>metric</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>as</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>for</span> <span style=''>SVM</span> <span style=''>training</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>none</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>generate</span> <span style=''>metrics</span> <span style=''>that</span> <span style=''>lead</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>for</span> <span style=''>SVM</span> <span style=''>RBF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>As</span> <span style=''>a</span> <span style=''>remedy</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>metric</span> <span style=''>learning</span> <span style=''>(SVML)</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>seamlessly</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mahalanobis</span> <span style=''>metric</span> <span style=''>with</span> <span style=''>the</span> <span style=''>training</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.101568068424804)
# 	representation (0.12829650748396293)
# 	segmentation (0.07555238774055595)
# 	knowledge (0.13186029935851745)
# 	architecture (0.09515324305060585)
# 	detection (0.11689237348538846)
# 	information (0.25552387740555954)
# 	different (0.26193870277975767)
# 	convolutional (0.12508909479686386)
# 	recognition (0.1407697790449038)
#
# Some Statistics words are:
# 	algorithm (0.3826479438314945)
# 	stochastic (0.13490471414242727)
# 	statistical (0.15897693079237712)
# 	theoretical (0.15245737211634905)
# 	variables (0.141925777331996)
# 	estimation (0.17953861584754263)
# 	distribution (0.17803410230692077)
# 	inference (0.20060180541624875)
# 	dimensional (0.19408224674022065)
# 	regression (0.18405215646940823)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="173d4f35-36a6-4a1a-8909-41edd4f7a4b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("173d4f35-36a6-4a1a-8909-41edd4f7a4b4")) {                    Plotly.newPlot(                        "173d4f35-36a6-4a1a-8909-41edd4f7a4b4",                        [{"x":["synthesis","challenging","recognition","discussing","furthermore","fascinating","preserving","evaluation","realistic","difficulties","excellent","highlighted","algorithms","introduced","probability","available","approaches","generative","traditional","adversarial","comprehensive","promising","complicated","databases","distributions","particularly","directions","segmentation","literature","presented","addressed","considered","applications","comparison","utilizing","ultrasound","tabulated","technique","robustness","interactivity","techniques","dimensional","investigate","autoencoder","recurrent","attractive","convergence","generation","previously","importantly","deconvolutional","convolutional","properties","variational","architecture","architectural","components","sequences","structure","understand","conformation","methodologies","molecular","resolution","currently","formulated","prediction","classification","described","substructures","intensive","meaningful","representation","segmented","successful","determining","determination","computational","fundamental","certainty","methodology","different","expressive","simulations","differently","reasoning","expressiveness","ambiguity","propagating","defeasible","formulation","framework","capability","streaming","reformulate","principled","generalized","stochastic","subsequently","stationarity","corresponding","regularization","distribution","regression","simulated","particular","constraint","parameter","ubiquitous","stationary","iteratively","application","underlying","incremental","regularized","sequentially","neuroimaging","estimating","variables","numerical","constraints","identifiability","expansion","optimization","assumptions","conditions","arbitrary","correlations","unsupervised","sufficient","primarily","estimation","probabilistic","tractable","experiments","statistics","including","important","challenges","extremely","requirements","highlight","complexity","incorporates","synthetic","challenge","experimental","substantial","dimensionality","difficulty","variations","hyperspectral","competitively","variation","diffusion","dramatically","clustering","detection","nonlinear","significant","segmenting","benchmark","discussed","information","extensive","efficiently","contribute","parameters","demonstrate","geometric","automatically","empirical","inherently","connectivity","uncertainty","estimators","effectively","difference","estimator","differences","covariance","statistical","comparing","parametric","estimated","populations","efficient","functional","interpretable","guarantees","characterizing","introduce","characterize","intervals","penalties","graphical","characterized","confidence","extension","backtracking","suggested","consequently","regulating","characteristic","extensions","decisions","theoretical","intriguing","performance","exponential","empirically","heuristic","embedding","transformations","proposing","addresses","optimizers","considers","correlation","autoencoders","multilayer","reduction","algorithm","consistently","multivariate","categorical","functions","eigenvector","component","weaknesses","maximally","correlated","computing","principal","coordinate","sequential","descriptors","simultaneously","especially","nevertheless","specifically","comparable","trajectories","conducted","descriptor","trajectory","effective","increasingly","distracting","appropriate","visualisation","distractors","behaviour","unders ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	visualisation
# 	ancillary
# 	nutrition
# 	minimizer
# 	correspondingly
# 	multilabel
# 	separators
# 	stabilisation
# 	disability
# 	oftentimes
# 	reconstructive
# 	unveiling
# 	acknowledging
# 	multitask
# 	underdamped
# 	sparsistent
# 	invariably
# 	criterions
# 	cytometry
# 	transports
# Some words which never appear in Statistics papers:
# 	fascinating
# 	ultrasound
# 	interactivity
# 	conformation
# 	certainty
# 	defeasible
# 	backtracking
# 	realistically
# 	smarandache
# 	configurable
# 	computacional
# 	instantaneously
# 	exactitude
# 	incentive
# 	manuscripts
# 	abductive
# 	processor
# 	imitation
# 	coherency
# 	recombination

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065885887727259e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7808333333333334
